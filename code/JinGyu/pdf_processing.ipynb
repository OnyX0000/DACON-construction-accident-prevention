# %%
from langchain_community.document_loaders import DirectoryLoader, PDFPlumberLoader
from pathlib import Path
import os

# PDF 파일이 있는 디렉토리 경로
pdf_dir = "C:\\Users\\user\\Documents\\GitHub\\DACON-construction-accident-prevention\\data\\pdf"  # 원하는 디렉토리 경로로 변경

# DirectoryLoader를 사용하여 모든 PDF 파일 로드
loader = DirectoryLoader(pdf_dir, glob="*.pdf", loader_cls=PDFPlumberLoader)  
all_documents = loader.load()  # 전체 PDF 파일 로드

# %%
all_documents[0].metadata
# Out:
# {'source': 'C:\\Users\\user\\Documents\\GitHub\\DACON-construction-accident-prevention\\data\\pdf\\F.C.M 교량공사 안전보건작업 지침.pdf',
#  'file_path': 'C:\\Users\\user\\Documents\\GitHub\\DACON-construction-accident-prevention\\data\\pdf\\F.C.M 교량공사 안전보건작업 지침.pdf',
#  'page': 0,
#  'total_pages': 24,
#  'Producer': 'ezPDF Builder Supreme',
#  'CreationDate': "D:20201223022000+09'00'",
#  'ModDate': "D:20201223022000+09'00'"}

# %%
import re
from langchain_core.documents import Document

# 📌 특정 파일명이 2번째 등장하기 전까지 삭제하는 함수
def remove_text_before_second_filename(documents, filename):
    """
    로드된 Document 리스트에서 파일명이 2번째 등장하기 전까지의 내용을 삭제하는 함수.
    """
    base_filename = os.path.splitext(filename)[0]  # 파일명에서 확장자 제거 (예: 'sample.pdf' -> 'sample')

    # 모든 문서 내용을 하나로 이어붙임
    full_text = "\n".join([doc.page_content for doc in documents])

    # 파일명이 등장하는 모든 위치 찾기
    matches = [match.start() for match in re.finditer(rf"\b{re.escape(base_filename)}\b", full_text, re.IGNORECASE)]

    # 파일명이 2번 이상 등장하는 경우, 두 번째 등장 이후의 텍스트만 유지
    if len(matches) >= 2:
        cleaned_text = full_text[matches[1]:].strip()
    else:
        cleaned_text = full_text  # 파일명이 2번 이상 등장하지 않으면 원본 유지

    # 새로운 Document 객체로 반환
    return [Document(page_content=cleaned_text, metadata={"source": filename})]

# 📌 각 PDF 파일별로 처리
processed_documents = []
for pdf_file in sorted(Path(pdf_dir).glob("*.pdf")):
    # 해당 PDF에 해당하는 문서들 필터링
    pdf_documents = [doc for doc in all_documents if pdf_file.name in doc.metadata.get("source", "")]
    
    if pdf_documents:
        cleaned_docs = remove_text_before_second_filename(pdf_documents, pdf_file.name)
        processed_documents.extend(cleaned_docs)

# ✅ 결과 확인 (첫 3개만 출력)
for doc in processed_documents[:3]:
    print(f"📄 Source: {doc.metadata.get('source', 'Unknown')}")
    print(doc.page_content[:300])  # 앞부분 300자만 출력
    print("-" * 40)
# Out:
# 📄 Source: F.C.M 교량공사 안전보건작업 지침.pdf
# F.C.M 교량공사 안전보건작업 지침
# 1. 목 적
# 이 지침은 산업안전보건기준에 관한 규칙(이하 “안전보건규칙”이라 한다.) 제
# 42조~제49조(추락에 의한 위험방지), 제133조~제150조(크레인, 이동식 크레인),
# 제369조(교량작업), 제328조~제337조(거푸집동바리 등)의 규정에 의거 콘크리
# 트 구조물 교량공사(F.C.M공법)의 안전한 작업방법 및 추락, 낙하, 붕괴, 감전
# 등의 재해를 예방하기 위하여 필요한 작업 단계별 안전사항 및 안전시설에 관
# 한 기술적 사항 등을 정함을 목적으로 한다.
# 2. 적용범위
# 이 지침은 바닥으로
# ----------------------------------------
# 📄 Source: I.L.M 교량공사 안전보건작업 지침.pdf
# I.L.M 교량공사 안전보건작업 지침
# 1. 목 적
# 이 지침은 산업안전보건기준에 관한 규칙(이하 “안전보건규칙”이라 한다.) 제
# 42조 내지 제49조의 규정에 의거 콘크리트 구조물 교량공사(I.L.M공법)의
# 안전한 작업방법 및 추락, 낙하, 붕괴, 감전 등의 재해를 예방하기 위하여
# 필요한 작업 단계별 안전사항 및 안전시설에 관한 기술적 사항 등을 정함을
# 목적으로 한다.
# 2. 적용범위
# 이 지침은 콘크리트 구조물 교량공사에서 상부구조의 가설공법 중 교대 후방에
# 설치한 주형 제작장에서 1세그먼트씩 제작하여 프리스트레스에 의해 일체화한
# 후
# ----------------------------------------
# 📄 Source: PCT거더 교량공사 안전보건작업지침.pdf
# KOSHA GUIDE
# C - 83 - 2013
# PCT거더 교량공사 안전보건작업
# 지침
# 2013. 9.
# 한국산업안전보건공단
#
# 안전보건작업지침의 개요
# ○ 작성자 : 한국안전학회 백신원
# ○ 제·개정 경과
# - 2013년 9월 건설안전분야 제정위원회 심의(제정)
# ○ 관련규격 및 자료
# - 최신 교량공학(동명사, 황학주)
# - 도로교 표준시방서(대한토목학회)
# - 교량공사(PCT거더공법) 시공자료
# - KS D ISO 10721-2 : 강구조물-제2부 : 조립 및 가설
# ○ 관련법규․규칙․고시 등
# - 산업안전보건기준에 관한 규칙 제379조~제393조
# ○
# ----------------------------------------

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.documents import Document

# 텍스트 스플리터 설정
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,  # 각 청크의 최대 길이
    chunk_overlap=100,  # 청크 간 겹치는 부분
    separators=['\n\n', '\n', '.', ' ']  # 텍스트 분할 기준
)

# 모든 문서를 청크 단위로 분할
split_documents = []
for doc in processed_documents:
    chunks = text_splitter.split_text(doc.page_content)  # 문서의 내용 분할
    
    # 분할된 청크를 새로운 Document 리스트에 저장
    for chunk in chunks:
        split_documents.append(Document(page_content=chunk, metadata=doc.metadata))

# 결과 확인 (첫 3개만 출력)
for doc in split_documents[:1]:
    print(doc.metadata, doc.page_content)
# Out:
# {'source': 'F.C.M 교량공사 안전보건작업 지침.pdf'} F.C.M 교량공사 안전보건작업 지침
# 1. 목 적
# 이 지침은 산업안전보건기준에 관한 규칙(이하 “안전보건규칙”이라 한다.) 제
# 42조~제49조(추락에 의한 위험방지), 제133조~제150조(크레인, 이동식 크레인),
# 제369조(교량작업), 제328조~제337조(거푸집동바리 등)의 규정에 의거 콘크리
# 트 구조물 교량공사(F.C.M공법)의 안전한 작업방법 및 추락, 낙하, 붕괴, 감전
# 등의 재해를 예방하기 위하여 필요한 작업 단계별 안전사항 및 안전시설에 관
# 한 기술적 사항 등을 정함을 목적으로 한다.
# 2. 적용범위
# 이 지침은 바닥으로부터 동바리를 사용하지 않고 교각위 주두부(Pier table)를
# 시공한 후 교각 양쪽의 교축방향으로 특수한 가설장비(F/T, Form traveller)를
# 이용해 좌․우로 하중의 균형을 맞추면서 세그먼트(Segment)의 콘크리트 타설,
# 프리스트레싱 도입을 순차적으로 반복하여 교량 상부 구조를 완성하는 현장타
# 설 F.C.M 공법에 적용한다.
# <그림 1> F.C.M 교량시공 전경
# - 1 -

# %%
def page_split(content):
    '''page별로 쪼개버림'''
    page_dict = {}
    i = 0
    while True:
        i += 1
        contents = content.split(f"- {i} -")
        if len(contents) != 2:
            break
        page_dict[str(i)] = contents[0]
        content = contents[1]
    return page_dict

page_split(all_documents[0].page_content)

# %%
import re
import os
from langchain_core.documents import Document

# 섹션 제목을 추출하는 함수
def extract_section(text):
    """
    문서 내에서 '1. 제목'과 같은 형식의 섹션을 찾는 함수.
    가장 먼저 등장하는 섹션을 반환하며, 없으면 'Unknown' 반환.
    """
    pattern = r"^\s*(\d+)\.\s+(.+)"  # '1. 제목' 또는 ' 1. 제목' 같은 패턴 탐색
    for line in text.split("\n"):  # 줄 단위로 검색
        match = re.match(pattern, line)
        if match:
            return match.group(2).strip()  # 숫자 다음에 오는 제목 부분만 반환
    return "Unknown"  # 해당하는 패턴이 없을 경우 기본값 반환

# 메타데이터 변환 함수
def custom_metadata(doc):
    metadata = doc.metadata  # 기존 메타데이터 가져오기
    text = doc.page_content  # 문서의 실제 내용 가져오기
    
    new_metadata = {
        "title": os.path.basename(metadata.get("source", "Unknown")),  # 파일 이름만 저장
        "page": metadata.get("page", 0) + 1,  # ✅ 페이지 번호를 1부터 시작하도록 수정
        "section": extract_section(text)  # ✅ 문서 내용에서 섹션 제목 추출
    }
    
    doc.metadata = new_metadata  # 기존 문서의 메타데이터 수정
    return doc

# 모든 문서의 메타데이터 변환 적용
documents = [custom_metadata(doc) for doc in split_documents]

# 결과 확인 (2개 출력)
for doc in documents[0:]:  
    print(doc.metadata)
# Out:
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '용어의 정의'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'F.C.M공법 작업절차'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '공통적인 안전조치사항'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '주두부 안전작업'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '이동식 작업대차 안전작업'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '세그먼트(Segment) 및 키 세그먼트(Key segment) 시공시 안전작업'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '처짐 안전관리(Camber control)'}
# {'title': 'F.C.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '작업계획 수립 시 검토사항'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '가시설물 제작 및 설치 안전작업'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '세그먼트(Segment) 제작․시공 안전작업'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '강선(tendon) 긴장작업 및 그라우팅 작업'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '압출작업 및 마감(도장 등) 작업'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'I.L.M 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '기타 안전조치 사항'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': '9.'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'PCT거더교의 특징 및 가설공법의 종류'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'PCT거더교의 특징 및 가설공법의 종류'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': '작업계획 수립 시 주요 검토사항'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': '시공전 공통 안전사항'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': '압출공법 안전작업'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': '크레인공법 안전작업'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': '상부슬래브 및 격벽 시공'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': '제작장 해체'}
# {'title': 'PCT거더 교량공사 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '가공송전선로 철탑 심형기초공사 안전보건작업 지침.pdf', 'page': 1, 'section': '8.'}
# {'title': '가공송전선로 철탑 심형기초공사 안전보건작업 지침.pdf', 'page': 1, 'section': '공사 준비'}
# {'title': '가공송전선로 철탑 심형기초공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '가공송전선로 철탑 심형기초공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '가공송전선로 철탑 심형기초공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '가공송전선로 철탑 심형기초공사 안전보건작업 지침.pdf', 'page': 1, 'section': '각입재 설치'}
# {'title': '가공송전선로 철탑 심형기초공사 안전보건작업 지침.pdf', 'page': 1, 'section': '기초 굴착작업시 유의사항'}
# {'title': '가공송전선로 철탑 심형기초공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '가공송전선로 철탑 심형기초공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '가공송전선로 철탑 심형기초공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '가설계단 설치 및 사용 안전보건작업 지침.pdf', 'page': 1, 'section': '8.'}
# {'title': '가설계단 설치 및 사용 안전보건작업 지침.pdf', 'page': 1, 'section': '산업안전보건기준에 관한 규칙 제21∼30조(제1편 총칙 제3장 통로)'}
# {'title': '가설계단 설치 및 사용 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '가설계단 설치 및 사용 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '가설계단 설치 및 사용 안전보건작업 지침.pdf', 'page': 1, 'section': '이동통로 선정기준'}
# {'title': '가설계단 설치 및 사용 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '가설계단 설치 및 사용 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '가설계단 설치 및 사용 안전보건작업 지침.pdf', 'page': 1, 'section': '안전난간'}
# {'title': '가설계단 설치 및 사용 안전보건작업 지침.pdf', 'page': 1, 'section': '기성품 가설계단의 응용'}
# {'title': '가설계단 설치 및 사용 안전보건작업 지침.pdf', 'page': 1, 'section': '가설계단 설치작업 중 안전 준수사항'}
# {'title': '가설계단 설치 및 사용 안전보건작업 지침.pdf', 'page': 1, 'section': '가설계단의 유지관리'}
# {'title': '가설계단 설치 및 사용 안전보건작업 지침.pdf', 'page': 1, 'section': '비계의 조립형 계단 설치기준 (출처 : BS EN 12811-1 : 2003)'}
# {'title': '가설구조물의 설계변경 요청 내용, 절차 등에 관한 작성지침.pdf', 'page': 1, 'section': '11.'}
# {'title': '가설구조물의 설계변경 요청 내용, 절차 등에 관한 작성지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '가설구조물의 설계변경 요청 내용, 절차 등에 관한 작성지침.pdf', 'page': 1, 'section': '설계변경 업무의 진행과정'}
# {'title': '가설구조물의 설계변경 요청 내용, 절차 등에 관한 작성지침.pdf', 'page': 1, 'section': '설계변경 근거 및 사전 검토'}
# {'title': '가설구조물의 설계변경 요청 내용, 절차 등에 관한 작성지침.pdf', 'page': 1, 'section': '설계변경 사유 및 절차'}
# {'title': '가설구조물의 설계변경 요청 내용, 절차 등에 관한 작성지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '가설구조물의 설계변경 요청 내용, 절차 등에 관한 작성지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '가설구조물의 설계변경 요청 내용, 절차 등에 관한 작성지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '가설구조물의 설계변경 요청 내용, 절차 등에 관한 작성지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '가설구조물의 설계변경 요청 내용, 절차 등에 관한 작성지침.pdf', 'page': 1, 'section': '기타 조치 사항'}
# {'title': '강관비계 안전작업지침.pdf', 'page': 1, 'section': '12.'}
# {'title': '강관비계 안전작업지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '강관비계 안전작업지침.pdf', 'page': 1, 'section': '강관비계 작업의 준비와 관리'}
# {'title': '강관비계 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강관비계 안전작업지침.pdf', 'page': 1, 'section': '강관비계의 재료'}
# {'title': '강관비계 안전작업지침.pdf', 'page': 1, 'section': '조 립'}
# {'title': '강관비계 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강관비계 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강관비계 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강관비계 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강관비계 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강관비계 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강관비계 안전작업지침.pdf', 'page': 1, 'section': '점검보수'}
# {'title': '강관비계 안전작업지침.pdf', 'page': 1, 'section': '해체'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '11.'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '강박스 거더 교량공사 작업절차'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '일반적인 안전조치사항'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '강박스 거더 설치 시 안전작업'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '슬래브 시공시 안전작업'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강박스거더 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': '강아치교 가설공법의 종류'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': '강아치교 상부구조(벤트가설공법) 시공순서'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': '강아치교 안전작업'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '강아치교(벤트공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '갱폼(Gang form) 제작 및 사용안전 지침.pdf', 'page': 1, 'section': '12'}
# {'title': '갱폼(Gang form) 제작 및 사용안전 지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '갱폼(Gang form) 제작 및 사용안전 지침.pdf', 'page': 1, 'section': '갱폼의 제작'}
# {'title': '갱폼(Gang form) 제작 및 사용안전 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '갱폼(Gang form) 제작 및 사용안전 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '갱폼(Gang form) 제작 및 사용안전 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '갱폼(Gang form) 제작 및 사용안전 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '갱폼(Gang form) 제작 및 사용안전 지침.pdf', 'page': 1, 'section': '갱폼 사용시의 작업안전'}
# {'title': '갱폼(Gang form) 제작 및 사용안전 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '갱폼(Gang form) 제작 및 사용안전 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '갱폼(Gang form) 제작 및 사용안전 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '갱폼(Gang form) 제작 및 사용안전 지침.pdf', 'page': 1, 'section': '갱폼 표준단면'}
# {'title': '갱폼(Gang form) 제작 및 사용안전 지침.pdf', 'page': 1, 'section': '갱폼 구성부재의 규격 표준'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': '8.'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': '목적 ···········································································································1'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': '굴착면 안전기울기 ···········································································7'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': '굴착비탈면 안전 사항'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': '굴착면 안전기울기'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': '국토교통부 건설공사 표준품셈(2014)'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': '한국전력공사 암판정기준(2010)'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': '한국엔지니어링 진흥협회 지반조사 표준품셈(2004)'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': '서울특별시 지반조사편람(2006)'}
# {'title': '건설공사 굴착면 안전기울기 기준에 관한 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 돌관작업 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '건설공사 돌관작업 안전보건작업 지침.pdf', 'page': 1, 'section': '건설공사 주체별 의무'}
# {'title': '건설공사 돌관작업 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 돌관작업 안전보건작업 지침.pdf', 'page': 1, 'section': '돌관작업 계획 수립 시 유의사항'}
# {'title': '건설공사 돌관작업 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 돌관작업 안전보건작업 지침.pdf', 'page': 1, 'section': '돌관작업 시 현장관리'}
# {'title': '건설공사 돌관작업 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 돌관작업 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 돌관작업 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 돌관작업 안전보건작업 지침.pdf', 'page': 1, 'section': '비상시 긴급 안전조치'}
# {'title': '건설공사 안전보건 설계 지침.pdf', 'page': 1, 'section': '11'}
# {'title': '건설공사 안전보건 설계 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '건설공사 안전보건 설계 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 안전보건 설계 지침.pdf', 'page': 1, 'section': '설계 시 고려할 안전·보건 기준'}
# {'title': '건설공사 안전보건 설계 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 안전보건 설계 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 안전보건 설계 지침.pdf', 'page': 1, 'section': '공사단계별 안전·보건 설계기준'}
# {'title': '건설공사 안전보건 설계 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 안전보건 설계 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 안전보건 설계 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 안전보건 설계 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 안전보건 설계 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사 안전보건 설계 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사의 고소작업대 안전보건작업지침.pdf', 'page': 1, 'section': '6.'}
# {'title': '건설공사의 고소작업대 안전보건작업지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '건설공사의 고소작업대 안전보건작업지침.pdf', 'page': 1, 'section': '건설공사의 고소작업대 종류'}
# {'title': '건설공사의 고소작업대 안전보건작업지침.pdf', 'page': 1, 'section': '고소작업대의 안전장치'}
# {'title': '건설공사의 고소작업대 안전보건작업지침.pdf', 'page': 1, 'section': '고소작업대 안전작업 준수사항'}
# {'title': '건설공사의 고소작업대 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사의 고소작업대 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사의 고소작업대 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설공사의 고소작업대 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': '12.'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': '차량계 건설기계'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': '기초공사용 건설기계'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': '양중기(크레인, 건설용 리프트)'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설기계 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장 용접용단 안전보건작업 기술지침.pdf', 'page': 1, 'section': '10.'}
# {'title': '건설현장 용접용단 안전보건작업 기술지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '건설현장 용접용단 안전보건작업 기술지침.pdf', 'page': 1, 'section': '유해\x9e위험요인별 안전보건 조치'}
# {'title': '건설현장 용접용단 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장 용접용단 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장 용접용단 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장 용접용단 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장 용접용단 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장 용접용단 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장 용접용단 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장 용접용단 안전보건작업 기술지침.pdf', 'page': 1, 'section': '다음의 지층에 접하거나 통하는 우물·수직갱·터널·잠함·피트 또는 그밖에 이와 유사한'}
# {'title': '건설현장 용접용단 안전보건작업 기술지침.pdf', 'page': 1, 'section': '간장·주류·효모 그 밖에 발효하는 물품이 들어 있거나 들어 있었던 탱크·창고 또는'}
# {'title': '건설현장의 중량물 취급 작업계획서(이동식크레인) 작성지침.pdf', 'page': 1, 'section': '8.'}
# {'title': '건설현장의 중량물 취급 작업계획서(이동식크레인) 작성지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장의 중량물 취급 작업계획서(이동식크레인) 작성지침.pdf', 'page': 1, 'section': '목적 ···········································································································1'}
# {'title': '건설현장의 중량물 취급 작업계획서(이동식크레인) 작성지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장의 중량물 취급 작업계획서(이동식크레인) 작성지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '건설현장의 중량물 취급 작업계획서(이동식크레인) 작성지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장의 중량물 취급 작업계획서(이동식크레인) 작성지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장의 중량물 취급 작업계획서(이동식크레인) 작성지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장의 중량물 취급 작업계획서(이동식크레인) 작성지침.pdf', 'page': 1, 'section': '작업계획서 작성시기 및 승인'}
# {'title': '건설현장의 중량물 취급 작업계획서(이동식크레인) 작성지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장의 중량물 취급 작업계획서(이동식크레인) 작성지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장의 중량물 취급 작업계획서(이동식크레인) 작성지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건설현장의 중량물 취급 작업계획서(이동식크레인) 작성지침.pdf', 'page': 1, 'section': '개별기기별, 사용일마다 작성한다.'}
# {'title': '건설현장의 중량물 취급 작업계획서(이동식크레인) 작성지침.pdf', 'page': 1, 'section': '평면도와 단면도를 구분하여 작성'}
# {'title': '건축물의 석공사(내외장) 안전보건작업 기술지침.pdf', 'page': 1, 'section': '11.'}
# {'title': '건축물의 석공사(내외장) 안전보건작업 기술지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '건축물의 석공사(내외장) 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건축물의 석공사(내외장) 안전보건작업 기술지침.pdf', 'page': 1, 'section': '자재 반입 및 준비작업 시 안전조치 사항'}
# {'title': '건축물의 석공사(내외장) 안전보건작업 기술지침.pdf', 'page': 1, 'section': '석재 설치 작업 시 안전조치 사항'}
# {'title': '건축물의 석공사(내외장) 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건축물의 석공사(내외장) 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건축물의 석공사(내외장) 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '건축물의 석공사(내외장) 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '경량철골 천장공사 안전보건작업 지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '경량철골 천장공사 안전보건작업 지침.pdf', 'page': 1, 'section': '경량철골 천장공사 일반사항'}
# {'title': '경량철골 천장공사 안전보건작업 지침.pdf', 'page': 1, 'section': '작업계획 수립 시 검토사항'}
# {'title': '경량철골 천장공사 안전보건작업 지침.pdf', 'page': 1, 'section': '경량철골 천장공사 작업별 안전조치 사항'}
# {'title': '경량철골 천장공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '경량철골 천장공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '경량철골 천장공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '경량철골 천장공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '곤돌라(Gondola) 안전보건작업 지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '곤돌라(Gondola) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '곤돌라(Gondola) 안전보건작업 지침.pdf', 'page': 1, 'section': '구성 및 구조'}
# {'title': '곤돌라(Gondola) 안전보건작업 지침.pdf', 'page': 1, 'section': '제작기준 및 안전장치의 종류'}
# {'title': '곤돌라(Gondola) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '곤돌라(Gondola) 안전보건작업 지침.pdf', 'page': 1, 'section': '곤돌라 안전점검 사항'}
# {'title': '곤돌라(Gondola) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '곤돌라(Gondola) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '곤돌라(Gondola) 안전보건작업 지침.pdf', 'page': 1, 'section': '곤돌라 작업 시 준수사항'}
# {'title': '곤돌라(Gondola) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '곤돌라(Gondola) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '관로매설공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': '관로매설공사 작업계획 수립 시 검토사항'}
# {'title': '관로매설공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': '관로매설공사 작업별 안전보건조치 사항'}
# {'title': '관로매설공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '8.'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '관로매설공사(유압식 추진공법)의 작업 순서'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '작업계획 수립 시 검토사항'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '작업 단계별 안전사항 및 안전시설에 관한 기술적 사항'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '관로매설공사(유압식 추진공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량 슬래브거푸집 해체용 작업대차 안전작업 지침.pdf', 'page': 1, 'section': '12.'}
# {'title': '교량 슬래브거푸집 해체용 작업대차 안전작업 지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '교량 슬래브거푸집 해체용 작업대차 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량 슬래브거푸집 해체용 작업대차 안전작업 지침.pdf', 'page': 1, 'section': '작업대차의 설계․제작 시 검토사항'}
# {'title': '교량 슬래브거푸집 해체용 작업대차 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량 슬래브거푸집 해체용 작업대차 안전작업 지침.pdf', 'page': 1, 'section': '작업대차의 조립작업 시 준수사항'}
# {'title': '교량 슬래브거푸집 해체용 작업대차 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량 슬래브거푸집 해체용 작업대차 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량 슬래브거푸집 해체용 작업대차 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량 슬래브거푸집 해체용 작업대차 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량 슬래브거푸집 해체용 작업대차 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량 슬래브거푸집 해체용 작업대차 안전작업 지침.pdf', 'page': 1, 'section': '작업대차를 이용한 거푸집 해체작업 시 주의사항'}
# {'title': '교량 슬래브거푸집 해체용 작업대차 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': '용어의 정의'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': '작업계획 수립 시 검토사항'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': '세그먼트(Segment)의 제작․운반․가설 안전작업'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': '런칭거더(Launching girder) 추진 안전작업'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': '안전시설 설치 및 안전조치 사항'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(P.S.M공법) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': '10.'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': '라멘교의 특징'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': '공통적인 안전조치사항'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': '기초공사(파일 항타)'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': '거푸집 설치'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': '철근 운반 및 조립'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': '콘크리트 타설'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': '콘크리트 양생'}
# {'title': '교량공사(라멘교) 안전보건작업지침.pdf', 'page': 1, 'section': '거푸집 해체'}
# {'title': '교량공사의 이동식 비계공법(MSS) 안전작업 지침.pdf', 'page': 1, 'section': '12.'}
# {'title': '교량공사의 이동식 비계공법(MSS) 안전작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '교량공사의 이동식 비계공법(MSS) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사의 이동식 비계공법(MSS) 안전작업 지침.pdf', 'page': 1, 'section': '작업계획 수립시 준수사항'}
# {'title': '교량공사의 이동식 비계공법(MSS) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사의 이동식 비계공법(MSS) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사의 이동식 비계공법(MSS) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사의 이동식 비계공법(MSS) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사의 이동식 비계공법(MSS) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사의 이동식 비계공법(MSS) 안전작업 지침.pdf', 'page': 1, 'section': '부대 안전시설 설치기준'}
# {'title': '교량공사의 이동식 비계공법(MSS) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '교량공사의 이동식 비계공법(MSS) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '계측관리 필요성 및 목적'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '계측관리 계획 절차 및 계측기 종류'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '계측기 선정 및 설치'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '계측 자료의 수집, 측정 빈도 및 분석'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '계측관리 방법 및 절차'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '안전관리 활용 및 특기사항'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '설치방법 및 측정방법'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '지중경사계 측정 예시'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '설치방법 및 측정방법'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '지하수위계 측정 예시'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '설치방법 및 측정방법'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '변형률계 측정 예시'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '설치방법 및 측정방법'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '하중계 측정 예시'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '설치방법 및 측정방법'}
# {'title': '굴착공사 계측관리 기술지침.pdf', 'page': 1, 'section': '건물경사계 측정 예시'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': '조 사'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': '굴착작업계획 수립 및 준비'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': '굴착작업 안전'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': '붕괴재해예방'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': '12.'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': '지하매설물 줄파기 작업 시 안전대책'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착공사 안전작업 지침.pdf', 'page': 1, 'section': '안전점검 사항'}
# {'title': '굴착기 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '굴착기 안전보건작업 지침.pdf', 'page': 1, 'section': '굴착기의 종류 및 선택 작업장치의 분류'}
# {'title': '굴착기 안전보건작업 지침.pdf', 'page': 1, 'section': '굴착기 작업중 위험요인 및 안전대책'}
# {'title': '굴착기 안전보건작업 지침.pdf', 'page': 1, 'section': '굴착기 안전작업 절차'}
# {'title': '굴착기 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착기 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착기 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착기 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착기 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '굴착기 안전보건작업 지침.pdf', 'page': 1, 'section': '- 퀵커플러 안전핀 체결여부 확인'}
# {'title': '굴착기 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '금속 커튼월(Curtain wall) 안전작업 지침.pdf', 'page': 1, 'section': '11'}
# {'title': '금속 커튼월(Curtain wall) 안전작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '금속 커튼월(Curtain wall) 안전작업 지침.pdf', 'page': 1, 'section': '부재 운반 및 적재 시 안전조치 사항'}
# {'title': '금속 커튼월(Curtain wall) 안전작업 지침.pdf', 'page': 1, 'section': '설치 시 안전조치 사항'}
# {'title': '금속 커튼월(Curtain wall) 안전작업 지침.pdf', 'page': 1, 'section': '2 고정용 부착철물 설치'}
# {'title': '금속 커튼월(Curtain wall) 안전작업 지침.pdf', 'page': 1, 'section': '3. 유니트 설치 작업'}
# {'title': '금속 커튼월(Curtain wall) 안전작업 지침.pdf', 'page': 1, 'section': '5 부재 보호 및 청소'}
# {'title': '기성 콘크리트 파일 항타 안전보건작업 지침.pdf', 'page': 1, 'section': '11.'}
# {'title': '기성 콘크리트 파일 항타 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '기성 콘크리트 파일 항타 안전보건작업 지침.pdf', 'page': 1, 'section': '안전작업계획 수립'}
# {'title': '기성 콘크리트 파일 항타 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '기성 콘크리트 파일 항타 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '기성 콘크리트 파일 항타 안전보건작업 지침.pdf', 'page': 1, 'section': '파일 항타 작업 단계별 안전사항 절차'}
# {'title': '기성 콘크리트 파일 항타 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '기성 콘크리트 파일 항타 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '기성 콘크리트 파일 항타 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '기성 콘크리트 파일 항타 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '낙하물 방지망 설치 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '낙하물 방지망 설치 지침.pdf', 'page': 1, 'section': '구조 및 재료'}
# {'title': '낙하물 방지망 설치 지침.pdf', 'page': 1, 'section': '설치 방법'}
# {'title': '낙하물 방지망 설치 지침.pdf', 'page': 1, 'section': '낙하물 방지망의 관리기준'}
# {'title': '낙하물 방호선반 설치 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '낙하물 방호선반 설치 지침.pdf', 'page': 1, 'section': '재료'}
# {'title': '낙하물 방호선반 설치 지침.pdf', 'page': 1, 'section': '강 도'}
# {'title': '낙하물 방호선반 설치 지침.pdf', 'page': 1, 'section': '설치기준'}
# {'title': '낙하물 방호선반 설치 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '낙하물 방호선반 설치 지침.pdf', 'page': 1, 'section': '사용 시 주의사항'}
# {'title': '내장공사의 안전보건작업 지침.pdf', 'page': 1, 'section': '11'}
# {'title': '내장공사의 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '내장공사의 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '내장공사의 안전보건작업 지침.pdf', 'page': 1, 'section': '안전·보건작업계획 수립'}
# {'title': '내장공사의 안전보건작업 지침.pdf', 'page': 1, 'section': '안전작업 공통 사항'}
# {'title': '내장공사의 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '내장공사의 안전보건작업 지침.pdf', 'page': 1, 'section': '천장공사 안전관리사항'}
# {'title': '내장공사의 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '내장공사의 안전보건작업 지침.pdf', 'page': 1, 'section': '벽체공사 안전관리사항'}
# {'title': '내장공사의 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '내장공사의 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '내장공사의 안전보건작업 지침.pdf', 'page': 1, 'section': 'M-Bar 천장틀'}
# {'title': '내장공사의 안전보건작업 지침.pdf', 'page': 1, 'section': 'T-Bar 천장틀'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': '11.'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': '냉동․냉장 물류창고 구조형식의 종류와 특징'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': '냉동․냉장 물류창고 단열공사의 화재 위험요인'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': '단열공사 중 화재예방을 위한 각 주체별 안전조치사항'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': '단열공사 중 화재예방을 위한 안전대책'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': '피난계획 및 응급구조'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': '사전 피해예방 대책 수립'}
# {'title': '냉동냉장 물류창고 단열공사 화재예방 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '단순 슬래브 콘크리트 타설 안전보건작업 지침.pdf', 'page': 1, 'section': '12.'}
# {'title': '단순 슬래브 콘크리트 타설 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '단순 슬래브 콘크리트 타설 안전보건작업 지침.pdf', 'page': 1, 'section': '단순 슬래브 콘크리트 타설 작업 시 안전작업 절차'}
# {'title': '단순 슬래브 콘크리트 타설 안전보건작업 지침.pdf', 'page': 1, 'section': '공사계획 수립 시 검토사항'}
# {'title': '단순 슬래브 콘크리트 타설 안전보건작업 지침.pdf', 'page': 1, 'section': '콘크리트 타설 시 준수사항'}
# {'title': '단순 슬래브 콘크리트 타설 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '단순 슬래브 콘크리트 타설 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '단순 슬래브 콘크리트 타설 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '단순 슬래브 콘크리트 타설 안전보건작업 지침.pdf', 'page': 1, 'section': '콘크리트 양생 시 준수사항'}
# {'title': '단순 슬래브 콘크리트 타설 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': '12.'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': '덤프트럭과 화물자동차의 종류'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': '덤프트럭과 화물자동차 중점 위험요인 및 안전대책'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': '덤프트럭과 화물자동차의 안전작업 절차'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '덤프트럭 및 화물자동차 안전작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '리모델링 안전보건작업 기술지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '리모델링 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '리모델링 안전보건작업 기술지침.pdf', 'page': 1, 'section': '사전조사'}
# {'title': '리모델링 안전보건작업 기술지침.pdf', 'page': 1, 'section': '리모델링 작업별 안전 준수사항'}
# {'title': '리모델링 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '리모델링 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '리모델링 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '리모델링 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '리모델링 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '리모델링 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '리모델링 안전보건작업 기술지침.pdf', 'page': 1, 'section': '기타 안전 준수사항'}
# {'title': '리모델링 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '미장공사 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '미장공사 안전보건작업 지침.pdf', 'page': 1, 'section': '미장공사 작업 전 안전조치 사항'}
# {'title': '미장공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '미장공사 안전보건작업 지침.pdf', 'page': 1, 'section': '벽 미장공사 중 안전조치사항'}
# {'title': '미장공사 안전보건작업 지침.pdf', 'page': 1, 'section': '바닥 미장공사 중 안전조치 사항'}
# {'title': '미장공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '미장공사 안전보건작업 지침.pdf', 'page': 1, 'section': '작업완료 후 안전조치사항'}
# {'title': '미장공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '밀폐공간의 방수공사 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '밀폐공간의 방수공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '밀폐공간의 방수공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '밀폐공간의 방수공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '밀폐공간의 방수공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '밀폐공간의 방수공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '밀폐공간의 방수공사 안전보건작업 지침.pdf', 'page': 1, 'section': '구조 및 응급처치'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': '공내뇌관(MS뇌관, LP뇌관)'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': '화약류의 취급'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': '전기 및 비전기발파'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '발파공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '블록식 보강토 옹벽 공사 안전보건작업 지침.pdf', 'page': 1, 'section': '11.'}
# {'title': '블록식 보강토 옹벽 공사 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '블록식 보강토 옹벽 공사 안전보건작업 지침.pdf', 'page': 1, 'section': '재료의 성능'}
# {'title': '블록식 보강토 옹벽 공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '블록식 보강토 옹벽 공사 안전보건작업 지침.pdf', 'page': 1, 'section': '안전작업절차'}
# {'title': '블록식 보강토 옹벽 공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '블록식 보강토 옹벽 공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '블록식 보강토 옹벽 공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '블록식 보강토 옹벽 공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '블록식 보강토 옹벽 공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '블록식 보강토 옹벽 공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '블록식 보강토 옹벽 공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '블록식 보강토 옹벽 공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '용어의 정의'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '작업계획 수립 시 검토사항'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '주경간 상부공 안전작업'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '주 케이블 시공 시 안전작업'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '사장교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '소규모 철근콘크리트 교량공사 거푸집 동바리 안전작업 지침.pdf', 'page': 1, 'section': '12.'}
# {'title': '소규모 철근콘크리트 교량공사 거푸집 동바리 안전작업 지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '소규모 철근콘크리트 교량공사 거푸집 동바리 안전작업 지침.pdf', 'page': 1, 'section': '공통 안전사항'}
# {'title': '소규모 철근콘크리트 교량공사 거푸집 동바리 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '소규모 철근콘크리트 교량공사 거푸집 동바리 안전작업 지침.pdf', 'page': 1, 'section': '하부구조물의 거푸집 동바리 설치작업'}
# {'title': '소규모 철근콘크리트 교량공사 거푸집 동바리 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '소규모 철근콘크리트 교량공사 거푸집 동바리 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '소규모 철근콘크리트 교량공사 거푸집 동바리 안전작업 지침.pdf', 'page': 1, 'section': '상부구조물의 거푸집 동바리 설치작업'}
# {'title': '소규모 철근콘크리트 교량공사 거푸집 동바리 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '소규모 철근콘크리트 교량공사 거푸집 동바리 안전작업 지침.pdf', 'page': 1, 'section': '거푸집 동바리 해체작업'}
# {'title': '수상 바지(Barge)선 이용 건설공사 안전작업 지침.pdf', 'page': 1, 'section': '12.'}
# {'title': '수상 바지(Barge)선 이용 건설공사 안전작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '수상 바지(Barge)선 이용 건설공사 안전작업 지침.pdf', 'page': 1, 'section': '바지(Barge)선 이용 작업'}
# {'title': '수상 바지(Barge)선 이용 건설공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '수상 바지(Barge)선 이용 건설공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '수상 바지(Barge)선 이용 건설공사 안전작업 지침.pdf', 'page': 1, 'section': '바지(Barge)선 작업 안전조치 사항'}
# {'title': '수상 바지(Barge)선 이용 건설공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '수상 바지(Barge)선 이용 건설공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '수상 바지(Barge)선 이용 건설공사 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# ...
# {'title': '해상 RCD 현장타설 말뚝공사(현수교, 사장교) 안전작업 지침.pdf', 'page': 1, 'section': '안전작업계획서 작성 시 검토사항'}
# {'title': '해상 RCD 현장타설 말뚝공사(현수교, 사장교) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해상 RCD 현장타설 말뚝공사(현수교, 사장교) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해상 RCD 현장타설 말뚝공사(현수교, 사장교) 안전작업 지침.pdf', 'page': 1, 'section': 'RCD 현장타설말뚝 공사 작업시 안전조치사항'}
# {'title': '해상 RCD 현장타설 말뚝공사(현수교, 사장교) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해상 RCD 현장타설 말뚝공사(현수교, 사장교) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해상 RCD 현장타설 말뚝공사(현수교, 사장교) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해상 RCD 현장타설 말뚝공사(현수교, 사장교) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해상 RCD 현장타설 말뚝공사(현수교, 사장교) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해상 RCD 현장타설 말뚝공사(현수교, 사장교) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해상 RCD 현장타설 말뚝공사(현수교, 사장교) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해상 RCD 현장타설 말뚝공사(현수교, 사장교) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해상 RCD 현장타설 말뚝공사(현수교, 사장교) 안전작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': '해체공사 전 확인사항'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': '해체공사 안전작업'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': '해체작업에 따른 공해방지'}
# {'title': '해체공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '작업계획 수립 시 검토사항'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '공통적인 안전조치 사항'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '케이블 안전작업'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': '보강거더 안전작업'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 교량공사 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': '7.'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': '현수교 주탑 시공순서'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': '안전작업계획서 작성시 검토사항'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': '현수교 주탑 작업 안전조치사항'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '현수교 주탑시공 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': '10'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': '주체별 주요 임무'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': '작업계획 수립'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': '고위험 작업별 안전보건 조치'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': '다음의 지층에 접하거나 통하는 우물·수직갱·터널·잠함·피트 또는 그밖에 이와 유사한'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': '간장·주류·효모 그 밖에 발효하는 물품이 들어 있거나 들어 있었던 탱크·창고 또는'}
# {'title': '화학플랜트 개보수 공사 안전보건작업 기술지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사 (SCW 공법) 안전보건작업지침.pdf', 'page': 1, 'section': '10.'}
# {'title': '흙막이공사 (SCW 공법) 안전보건작업지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '흙막이공사 (SCW 공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'SCW 공법의 시공순서'}
# {'title': '흙막이공사 (SCW 공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사 (SCW 공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사 (SCW 공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'SCW 공법의 각 공정별 안전조치 사항'}
# {'title': '흙막이공사 (SCW 공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사 (SCW 공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사 (SCW 공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사 (SCW 공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사 (SCW 공법) 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사 (SCW 공법) 안전보건작업지침.pdf', 'page': 1, 'section': '기타 안전조치 사항'}
# {'title': '흙막이공사(C.I.P공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '목적'}
# {'title': '흙막이공사(C.I.P공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'C.I.P 흙막이공사 전 안전조치 사항'}
# {'title': '흙막이공사(C.I.P공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'C.I.P 흙막이공사 안전조치 사항'}
# {'title': '흙막이공사(C.I.P공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(C.I.P공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(C.I.P공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(C.I.P공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(C.I.P공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(C.I.P공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '차수 그라우팅(Grouting)작업 안전조치 사항'}
# {'title': '흙막이공사(C.I.P공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Earth Anchor 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '8.'}
# {'title': '흙막이공사(Earth Anchor 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '흙막이공사(Earth Anchor 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '건설주체별 의무'}
# {'title': '흙막이공사(Earth Anchor 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Earth Anchor 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Earth Anchor 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '안전작업절차'}
# {'title': '흙막이공사(Earth Anchor 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Earth Anchor 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Earth Anchor 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Earth Anchor 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Earth Anchor 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Earth Anchor 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '그 밖의 안전조치사항'}
# {'title': '흙막이공사(Soil Nailing 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '8.'}
# {'title': '흙막이공사(Soil Nailing 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '흙막이공사(Soil Nailing 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '건설주체별 의무'}
# {'title': '흙막이공사(Soil Nailing 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Soil Nailing 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Soil Nailing 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Soil Nailing 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '안전작업절차'}
# {'title': '흙막이공사(Soil Nailing 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Soil Nailing 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Soil Nailing 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Soil Nailing 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(Soil Nailing 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '기타 안전조치사항'}
# {'title': '흙막이공사(강널말뚝, Sheet Pile)의 안전보건작업지침.pdf', 'page': 1, 'section': '7.'}
# {'title': '흙막이공사(강널말뚝, Sheet Pile)의 안전보건작업지침.pdf', 'page': 1, 'section': '강널말뚝 흙막이공사 시공전 안전조치 사항'}
# {'title': '흙막이공사(강널말뚝, Sheet Pile)의 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(강널말뚝, Sheet Pile)의 안전보건작업지침.pdf', 'page': 1, 'section': '강널말뚝 흙막이공사 안전조치 사항'}
# {'title': '흙막이공사(강널말뚝, Sheet Pile)의 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(강널말뚝, Sheet Pile)의 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(강널말뚝, Sheet Pile)의 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(강널말뚝, Sheet Pile)의 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(강널말뚝, Sheet Pile)의 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(강널말뚝, Sheet Pile)의 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(강널말뚝, Sheet Pile)의 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(강널말뚝, Sheet Pile)의 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(강널말뚝, Sheet Pile)의 안전보건작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(강널말뚝, Sheet Pile)의 안전보건작업지침.pdf', 'page': 1, 'section': '기타 안전조치 사항'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': '11.'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': '띠장 긴장 공법의 시공흐름도'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': '띠장 긴장 공법의 일반 안전조치 사항'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': '띠장 긴장 공법의 각 공정별 안전조치 사항'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(띠장긴장공법, Prestressed Wale Method) 안전보건 작업지침.pdf', 'page': 1, 'section': '기타 안전조치 사항'}
# {'title': '흙막이공사(엄지말뚝 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '8.'}
# {'title': '흙막이공사(엄지말뚝 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '흙막이공사(엄지말뚝 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(엄지말뚝 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '흙막이공사 전 안전조치 사항'}
# {'title': '흙막이공사(엄지말뚝 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '흙막이공사 시 안전조치 사항'}
# {'title': '흙막이공사(엄지말뚝 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(엄지말뚝 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(엄지말뚝 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(엄지말뚝 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(엄지말뚝 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(엄지말뚝 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '굴착작업 시 안전조치 사항'}
# {'title': '흙막이공사(엄지말뚝 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(엄지말뚝 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': '흙막이 가시설 해체 시 안전조치 사항'}
# {'title': '흙막이공사(엄지말뚝 공법) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': '11.'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': '목 적'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': '지하연속벽 공법의 시공순서'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': '작업전 검토 및 준비사항'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': '각 공정별 안전보건 작업기준'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
# {'title': '흙막이공사(지하연속벽) 안전보건작업 지침.pdf', 'page': 1, 'section': 'Unknown'}
